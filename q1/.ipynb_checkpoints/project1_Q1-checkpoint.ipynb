# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # AirBnB Data Analysis

# %%
#Loading in AirBnB data CSV
listing_data = pd.read_csv("Resources/listings.csv")
listing_df = pd.DataFrame(listing_data)
listing_df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20230902023033   2023-09-02
# 1  5858  https://www.airbnb.com/rooms/5858  20230902023033   2023-09-02
# 2  8142  https://www.airbnb.com/rooms/8142  20230902023033   2023-09-02
# 3  8339  https://www.airbnb.com/rooms/8339  20230902023033   2023-09-02
# 4  8739  https://www.airbnb.com/rooms/8739  20230902023033   2023-09-02
#
#         source                                               name  \
# 0  city scrape  Serviced apartment in San Francisco · ★4.87 · ...
# 1  city scrape  Rental unit in San Francisco · ★4.88 · 2 bedro...
# 2  city scrape  Rental unit in San Francisco · ★4.70 · 1 bedro...
# 3  city scrape  Condo in San Francisco · ★4.87 · 1 bedroom · 1...
# 4  city scrape  Condo in San Francisco · ★4.92 · 1 bedroom · 1...
#
#                                          description  \
# 0  Our bright garden unit overlooks a lovely back...
# 1  We live in a large Victorian house on a quiet ...
# 2  Nice and good public transportation.  7 minute...
# 3  Pls email before booking. <br />Interior featu...
# 4  Welcome to "The Mission," the sunniest neighbo...
#
#                                neighborhood_overview  \
# 0  Quiet cul de sac in friendly neighborhood<br /...
# 1  I love how our neighborhood feels quiet but is...
# 2  N Juda Muni, Bus and UCSF Shuttle.<br /><br />...
# 3                                                NaN
# 4  Located between Valencia Street and Dolores Pa...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/b7c2a199-4c17...     1169  ...
# 1  https://a0.muscache.com/pictures/17714/3a7aea1...     8904  ...
# 2  https://a0.muscache.com/pictures/8e27fdaa-c207...    21994  ...
# 3  https://a0.muscache.com/pictures/miso/Hosting-...    24215  ...
# 4  https://a0.muscache.com/pictures/80811/7a57d0e...     7149  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.89                   4.97                4.75
# 1                        4.85                   4.77                4.68
# 2                        4.80                   4.70                4.70
# 3                        5.00                   4.94                4.75
# 4                        4.96                   4.93                4.75
#
#                      license instant_bookable calculated_host_listings_count  \
# 0  City Registration Pending                f                              1
# 1                        NaN                f                              1
# 2                        NaN                f                             15
# 3                STR-0000264                f                              2
# 4                STR-0000028                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           0
# 3                                           2
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                           15
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.36
# 1                                           0              0.64
# 2                                           0              0.09
# 3                                           0              0.16
# 4                                           0              4.62
#
# [5 rows x 75 columns]

# %%
#Making DF of relevant info
bnbinfo_df = listing_df[["host_id","price"]]

bnbinfo_df
# Out:
#         host_id    price
# 0          1169  $187.00
# 1          8904  $235.00
# 2         21994   $56.00
# 3         24215  $480.00
# 4          7149  $122.00
# ...         ...      ...
# 7413    2466011  $383.00
# 7414  485721712  $130.00
# 7415  370838667   $34.00
# 7416  304721494  $281.00
# 7417   34742746   $79.00
#
# [7418 rows x 2 columns]

# %%
#Renaming columns
bnbinfo_df = bnbinfo_df.rename(columns={"host_id":"Host ID","price":"Price per Night"})
bnbinfo_df
# Out:
#         Host ID Price per Night
# 0          1169         $187.00
# 1          8904         $235.00
# 2         21994          $56.00
# 3         24215         $480.00
# 4          7149         $122.00
# ...         ...             ...
# 7413    2466011         $383.00
# 7414  485721712         $130.00
# 7415  370838667          $34.00
# 7416  304721494         $281.00
# 7417   34742746          $79.00
#
# [7418 rows x 2 columns]

# %%
#Reminder to convert price to int/float
bnbinfo_df.dtypes
# Out:
# Host ID             int64
# Price per Night    object
# dtype: object

# %%
#Converting price to int and calculating price per month
bnbinfo_df["Price per Night"] = bnbinfo_df["Price per Night"].replace("[$,]", "", regex=True).astype(float)
bnbinfo_df["Price per Month"] = bnbinfo_df["Price per Night"]*30
bnbinfo_df
# Out:
#         Host ID  Price per Night  Price per Month
# 0          1169            187.0           5610.0
# 1          8904            235.0           7050.0
# 2         21994             56.0           1680.0
# 3         24215            480.0          14400.0
# 4          7149            122.0           3660.0
# ...         ...              ...              ...
# 7413    2466011            383.0          11490.0
# 7414  485721712            130.0           3900.0
# 7415  370838667             34.0           1020.0
# 7416  304721494            281.0           8430.0
# 7417   34742746             79.0           2370.0
#
# [7418 rows x 3 columns]

# %%
#Checking data types one more time
bnbinfo_df.dtypes
# Out:
# Host ID              int64
# Price per Night    float64
# Price per Month    float64
# dtype: object

# %%
#Binning AirBNB Data
bins = [0,499.99, 999.99, 1499.99, 1999.99, 2499.99, 2999.99, 15000.00]
group_names = ["Less than $500","$500 to 999", "$1,000 to 1,499", "$1,500 to 1,999", "$2,000 to 2,499", "$2,500 to 2,999",
              "$3,000 or more"]
bnbinfo_df["Groups"] = pd.cut(bnbinfo_df["Price per Month"], bins, labels=group_names, include_lowest=True)
bnbinfo_df
# Out:
#         Host ID  Price per Night  Price per Month           Groups
# 0          1169            187.0           5610.0   $3,000 or more
# 1          8904            235.0           7050.0   $3,000 or more
# 2         21994             56.0           1680.0  $1,500 to 1,999
# 3         24215            480.0          14400.0   $3,000 or more
# 4          7149            122.0           3660.0   $3,000 or more
# ...         ...              ...              ...              ...
# 7413    2466011            383.0          11490.0   $3,000 or more
# 7414  485721712            130.0           3900.0   $3,000 or more
# 7415  370838667             34.0           1020.0  $1,000 to 1,499
# 7416  304721494            281.0           8430.0   $3,000 or more
# 7417   34742746             79.0           2370.0  $2,000 to 2,499
#
# [7418 rows x 4 columns]

# %%
#Counting price groups
price_groups_count = bnbinfo_df["Groups"].value_counts()
price_groups_count.head()
# Out:
# Groups
# $3,000 or more     5079
# $2,500 to 2,999     637
# $2,000 to 2,499     475
# $1,500 to 1,999     469
# $1,000 to 1,499     171
# Name: count, dtype: int64

# %%
#Making groupby object
price_groups = bnbinfo_df.groupby(["Groups"])
print(price_groups)
price_groups.count()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000208BB0AF4F0>
#                  Host ID  Price per Night  Price per Month
# Groups
# Less than $500         0                0                0
# $500 to 999           14               14               14
# $1,000 to 1,499      171              171              171
# $1,500 to 1,999      469              469              469
# $2,000 to 2,499      475              475              475
# $2,500 to 2,999      637              637              637
# $3,000 or more      5079             5079             5079

# %%
#Creating variable to find percentage of AirBnBs
total_bnb = (bnbinfo_df["Host ID"].count())
total_bnb
# Out:
# 7418

# %%
#Adding percentages column to DataFrame
price_groups_df = pd.DataFrame(price_groups[["Price per Month"]].count())

price_groups_df = price_groups_df.rename(columns={'Price per Month': '# of AirBnBs'})
price_groups_df["% of AirBnBs"] = (price_groups_df["# of AirBnBs"] / total_bnb.sum()) * 100

price_groups_df
# Out:
#                  # of AirBnBs  % of AirBnBs
# Groups
# Less than $500              0      0.000000
# $500 to 999                14      0.188730
# $1,000 to 1,499           171      2.305204
# $1,500 to 1,999           469      6.322459
# $2,000 to 2,499           475      6.403343
# $2,500 to 2,999           637      8.587220
# $3,000 or more           5079     68.468590

# %%
#Reducing AirBnB dataframe to solely percentages for graphing
percent_bnb = price_groups_df[["% of AirBnBs"]]
percent_bnb
# Out:
#                  % of AirBnBs
# Groups
# Less than $500       0.000000
# $500 to 999          0.188730
# $1,000 to 1,499      2.305204
# $1,500 to 1,999      6.322459
# $2,000 to 2,499      6.403343
# $2,500 to 2,999      8.587220
# $3,000 or more      68.468590

# %%
#Graphing AirBnB data
bnb_graph = percent_bnb.plot(kind="bar", title="Price of Monthly Stay in AirBnBs in San Francisco", rot=65)
plt.ylabel("% of AirBnBs")
plt.xlabel("Price Groups")
plt.tight_layout()
plt.savefig("Images/monthly_airbnb.png")

# %% [markdown]
# # Census Data Analysis

# %%
#Loading Census data csv
census_data = pd.read_csv("Resources/census_data.csv")
census_df = pd.DataFrame(census_data)
census_df
# Out:
#                    Label (Grouping)  \
# 0                 HOUSING OCCUPANCY
# 1               Total housing units
# 2            Occupied housing units
# 3              Vacant housing units
# 4            Homeowner vacancy rate
# ..                              ...
# 155            20.0 to 24.9 percent
# 156            25.0 to 29.9 percent
# 157            30.0 to 34.9 percent
# 158            35.0 percent or more
# 159                    Not computed
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Estimate  \
# 0                                                  NaN
# 1                                            1,837,144
# 2                                            1,716,654
# 3                                              120,490
# 4                                                  0.7
# ..                                                 ...
# 155                                             98,368
# 156                                             83,857
# 157                                             62,386
# 158                                            277,537
# 159                                             32,128
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Margin of Error  \
# 0                                                  NaN
# 1                                               ±1,170
# 2                                               ±4,203
# 3                                               ±3,705
# 4                                                 ±0.1
# ..                                                 ...
# 155                                             ±2,521
# 156                                             ±2,292
# 157                                             ±2,292
# 158                                             ±3,963
# 159                                             ±1,421
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Percent  \
# 0                                                  NaN
# 1                                            1,837,144
# 2                                                93.4%
# 3                                                 6.6%
# 4                                                  (X)
# ..                                                 ...
# 155                                              13.3%
# 156                                              11.4%
# 157                                               8.5%
# 158                                              37.6%
# 159                                                (X)
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Percent Margin of Error
# 0                                                  NaN
# 1                                                  (X)
# 2                                                 ±0.2
# 3                                                 ±0.2
# 4                                                  (X)
# ..                                                 ...
# 155                                               ±0.3
# 156                                               ±0.3
# 157                                               ±0.3
# 158                                               ±0.5
# 159                                                (X)
#
# [160 rows x 5 columns]

# %%
#Grabbing relevant data out of Census CSV
census_df = census_df.iloc[142:149]
census_df
# Out:
#              Label (Grouping)  \
# 142            Less than $500
# 143              $500 to $999
# 144          $1,000 to $1,499
# 145          $1,500 to $1,999
# 146          $2,000 to $2,499
# 147          $2,500 to $2,999
# 148            $3,000 or more
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Estimate  \
# 142                                             41,647
# 143                                             52,397
# 144                                             98,387
# 145                                            137,098
# 146                                            143,406
# 147                                            104,375
# 148                                            170,855
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Margin of Error  \
# 142                                             ±1,873
# 143                                             ±1,663
# 144                                             ±2,583
# 145                                             ±3,113
# 146                                             ±2,710
# 147                                             ±2,738
# 148                                             ±3,163
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Percent  \
# 142                                               5.6%
# 143                                               7.0%
# 144                                              13.2%
# 145                                              18.3%
# 146                                              19.2%
# 147                                              14.0%
# 148                                              22.8%
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Percent Margin of Error
# 142                                               ±0.2
# 143                                               ±0.2
# 144                                               ±0.3
# 145                                               ±0.4
# 146                                               ±0.4
# 147                                               ±0.4
# 148                                               ±0.4

# %%
#Grabbing relevant columns out of Census DataFrame
census_df = census_df[["Label (Grouping)", "San Francisco-Oakland-Berkeley, CA Metro Area!!Percent"]]
census_df
# Out:
#              Label (Grouping)  \
# 142            Less than $500
# 143              $500 to $999
# 144          $1,000 to $1,499
# 145          $1,500 to $1,999
# 146          $2,000 to $2,499
# 147          $2,500 to $2,999
# 148            $3,000 or more
#
#     San Francisco-Oakland-Berkeley, CA Metro Area!!Percent
# 142                                               5.6%
# 143                                               7.0%
# 144                                              13.2%
# 145                                              18.3%
# 146                                              19.2%
# 147                                              14.0%
# 148                                              22.8%

# %%
#Renaming Census Dataframe columns
census_df = census_df.rename(columns={"Label (Grouping)":"Groups", 
                                      "San Francisco-Oakland-Berkeley, CA Metro Area!!Percent": "% of People"})

census_df = census_df.set_index("Groups")
census_df
# Out:
#                          % of People
# Groups
#         Less than $500          5.6%
#         $500 to $999            7.0%
#         $1,000 to $1,499       13.2%
#         $1,500 to $1,999       18.3%
#         $2,000 to $2,499       19.2%
#         $2,500 to $2,999       14.0%
#         $3,000 or more         22.8%

# %%
#Removing percent signs and converting number to int
census_df['% of People'] = census_df['% of People'].replace("[%]", "", regex=True).astype(float)
census_df
# Out:
#                           % of People
# Groups
#         Less than $500            5.6
#         $500 to $999              7.0
#         $1,000 to $1,499         13.2
#         $1,500 to $1,999         18.3
#         $2,000 to $2,499         19.2
#         $2,500 to $2,999         14.0
#         $3,000 or more           22.8

# %%
#Fixing formatting in Census Dataframe index
census_df = census_df.rename(index={'        Less than $500': 'Less than $500',
                    '        $500 to $999': '$500 to 999',
                    '        $1,000 to $1,499': '$1,000 to 1,499',
                   '        $1,500 to $1,999': '$1,500 to 1,999',
                   '        $2,000 to $2,499': '$2,000 to 2,499',
                   '        $2,500 to $2,999': '$2,500 to 2,999',
                   '        $3,000 or more': '$3,000 or more'})
census_df
# Out:
#                  % of People
# Groups
# Less than $500           5.6
# $500 to 999              7.0
# $1,000 to 1,499         13.2
# $1,500 to 1,999         18.3
# $2,000 to 2,499         19.2
# $2,500 to 2,999         14.0
# $3,000 or more          22.8

# %%
#Graphing Census Data
rent_graph = census_df.plot(kind="bar", title="Price of Monthly Rent in San Francisco", rot=65)
plt.ylabel("% of People")
plt.xlabel("Price Groups")
plt.tight_layout()
plt.savefig("Images/sanfran_rent.png")

# %% [markdown]
# # Merging both DataFrames to make one graph for easier visual comparison of data

# %%
#Merging AirBnB and Census dataframes
merged_df = pd.merge(census_df,percent_bnb, left_index=True, right_index=True)
merged_df
# Out:
#                  % of People  % of AirBnBs
# Groups
# Less than $500           5.6      0.000000
# $500 to 999              7.0      0.188730
# $1,000 to 1,499         13.2      2.305204
# $1,500 to 1,999         18.3      6.322459
# $2,000 to 2,499         19.2      6.403343
# $2,500 to 2,999         14.0      8.587220
# $3,000 or more          22.8     68.468590

# %%
merged_graph =  merged_df.plot(kind="bar", rot=65)
plt.xlabel("Price Groups")
plt.ylabel("Percentages")
plt.title("Monthly AirBnB Stay vs Rent in San Francisco")
plt.tight_layout()
plt.savefig("Images/comparison_graph.png")
